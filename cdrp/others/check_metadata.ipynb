# %%
import pandas as pd

# %%
df = pd.read_csv("/raid/data/cellpainting/CDRP/inputs/metadata/index.csv")

# %%
df.groupby("Replicate_Use").count()
# Out:
#                Metadata_Plate  Metadata_Well  Metadata_Site  Plate_Map_Name  \
# Replicate_Use
# None                    57216          57216          57216           57216
# Training                40320          40320          40320           40320
# Validation              26880          26880          26880           26880
#
#                Assay_Plate_Barcode    DNA    RNA     ER    AGP   Mito  \
# Replicate_Use
# None                         57216  57216  57216  57216  57216  57216
# Training                     40320  40320  40320  40320  40320  40320
# Validation                   26880  26880  26880  26880  26880  26880
#
#                Compound  Concentration  Treatment  Treatment_Replicate
# Replicate_Use
# None              36462          36462      57216                57216
# Training          40302          40302      40320                40320
# Validation        26868          26868      26880                26880

# %%
df[df.Replicate_Use == "Validation"].groupby("Treatment").count()
# Out:
#                                     Metadata_Plate  Metadata_Well  \
# Treatment
# BRD-A00100033-001-04-8@3.480779138              12             12
# BRD-A00267231-001-01-1@5                        12             12
# BRD-A00327403-103-01-9@5                        12             12
# BRD-A00520476-001-03-3@5                        12             12
# BRD-A00827783-001-04-8@5                        12             12
# ...                                            ...            ...
# BRD-K98174813-001-05-7@5.897437893              12             12
# BRD-K98281970-001-02-6@5                        12             12
# BRD-K98297262-001-01-1@5                        12             12
# BRD-K98521173-001-03-8@3.026074779              12             12
# NA@NA                                           12             12
#
#                                     Metadata_Site  Plate_Map_Name  \
# Treatment
# BRD-A00100033-001-04-8@3.480779138             12              12
# ...
